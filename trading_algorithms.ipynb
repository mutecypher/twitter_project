# %% [markdown]
# ## Four Factor Model Playground
#
# size: small firms
# book-to-market value
# beta" volatility "market rises 1% stock rises 1%" beta of 1
# momentum: did well will continue to go well, either earnings or stock price
#
# look up VIX
# and SPY

# %%
from fredapi import Fred
import pandas as pd

from matplotlib import pyplot

API_KEY ='51fa986d643a392cc8103f7af8440123'
fred = Fred(api_key=API_KEY)
##
SP500 = fred.get_series('SP500')
SP500.to_csv('S&P500.csv')
SP500.plot()
pyplot.title('S&P500')
pyplot.show()

##
Gas = fred.get_series('GASREGCOVW')
Gas.to_csv('Gas.csv')
##
Personal_Income = fred.get_series('PINCOME')
Personal_Income.to_csv('Personal_Income.csv')
Personal_Income.plot()
pyplot.title('Personal Income')
pyplot.show()
##
Ten_year_tresuries = fred.get_series('DGS10')
Ten_year_tresuries.to_csv('Ten_year_tresuries.csv')
##
Consumer_price_index = fred.get_series('CPIAUCSL')
Consumer_price_index.to_csv('Consumer_price_index.csv')
##
Unemployment_rate = fred.get_series('UNRATE')
Unemployment_rate.to_csv('Unemployment_rate.csv')
Unemployment_rate.plot()
pyplot.title('Unemployment Rate')
pyplot.show()
##
Unemployment_initial_claims = fred.get_series('ICSA')
Unemployment_initial_claims.to_csv('Unemployment_initial_claims.csv')
Unemployment_initial_claims.plot()
pyplot.title('Unemployment Initial Claims')
pyplot.show()
##
Effective_fed_funding_rate = fred.get_series('FEDFUNDS')
Effective_fed_funding_rate.to_csv('Effective_fed_funding_rate.csv')
##
Dollar_to_Euro = fred.get_series('DEXUSEU')
Dollar_to_Euro.to_csv('Dollar_to_Euro.csv')
###
Industrial_Production_Index = fred.get_series('INDPRO')
Industrial_Production_Index.to_csv('Industrial_Production_Index.csv')
Industrial_Production_Index.plot()
pyplot.title('Industrial Production Index')
pyplot.show()
##
Dow_Jones_industrial = fred.get_series('DJIA')
Dow_Jones_industrial.to_csv('Dow_Jones_industrial.csv')
##

SandP500_Volatility_index = fred.get_series('VIXCLS')
SandP500_Volatility_index.to_csv('SandP500_Volatility_index.csv')
##

NASDAC_100_Volatility_index = fred.get_series('VXNCLS')
NASDAC_100_Volatility_index.to_csv('NASDAC_100_Volatility_index.csv')
NASDAC_100_Volatility_index.plot()
pyplot.title('NASDAC 100 Volatility Index')
pyplot.show()
##
Year_30_mortgage_rate = fred.get_series('MORTGAGE30US')
Year_30_mortgage_rate.to_csv('Year_30_mortgage_rate.csv')
##
M2_household_assets = fred.get_series('M2')
M2_household_assets.to_csv('M2_household_assets.csv')

##

print("The S&P 500 was \n", SP500.tail())
print("Personal income is\n", Personal_Income.tail())
print("Gas prices weekly are \n", Gas.tail())
print("Ten year treasuries are \n", Ten_year_tresuries.tail())
print("CPI is \n" , Consumer_price_index.tail())
print("Unemployment rate is \n" , Unemployment_rate.tail())
print("Unemployment inital claims are \n " , Unemployment_initial_claims.tail())
print("Effective federal funding rate is  \n " , Effective_fed_funding_rate.tail())
print("One Dollar to One Euro rate is  \n " , Dollar_to_Euro.tail())
print("Industrial Production Index is  \n " , Industrial_Production_Index.tail())
print("Dow Jones industrial is  \n " , Dow_Jones_industrial.tail())
print("CBOE S&P Volatility index is  \n " , SandP500_Volatility_index.tail())
print("30 year mortgate rates are  \n " , Year_30_mortgage_rate.tail())
print("M2 houshold assets \n " , M2_household_assets.tail())
# Out:
# The S&P 500 was
#  2020-07-17    3224.73
# 2020-07-20    3251.84
# 2020-07-21    3257.30
# 2020-07-22    3276.02
# 2020-07-23    3235.66
# dtype: float64
# Personal income is
#  2019-01-01    18355.447
# 2019-04-01    18555.861
# 2019-07-01    18676.885
# 2019-10-01    18845.059
# 2020-01-01    18942.151
# dtype: float64
# Gas prices weekly are
#  2020-06-22    2.048
# 2020-06-29    2.094
# 2020-07-06    2.100
# 2020-07-13    2.113
# 2020-07-20    2.099
# dtype: float64
# Ten year treasuries are
#  2020-07-17    0.64
# 2020-07-20    0.62
# 2020-07-21    0.61
# 2020-07-22    0.60
# 2020-07-23    0.59
# dtype: float64
# CPI is
#  2020-02-01    259.050
# 2020-03-01    257.953
# 2020-04-01    255.902
# 2020-05-01    255.768
# 2020-06-01    257.214
# dtype: float64
# Unemployment rate is
#  2020-02-01     3.5
# 2020-03-01     4.4
# 2020-04-01    14.7
# 2020-05-01    13.3
# 2020-06-01    11.1
# dtype: float64
# Unemployment inital claims are
#   2020-06-20    1482000.0
# ...
